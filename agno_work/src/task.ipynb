# %% [markdown]
# флоу поиска информации в интернете с помощью duckduckgo

# %%
from agno.agent import Agent
from agno.workflow import Workflow
from agno.models.cohere import Cohere
from agno.tools.duckduckgo import DuckDuckGoTools

researcher = Agent(
            model=Cohere(
                        id="command-a-03-2025",
                        api_key=,
                        ),
            tools=[
                DuckDuckGoTools(),
            ],
            markdown=True
            )

research_workflow = Workflow(
    name="Search info",
    steps=[researcher]
)

while True:
    user_input = input()
    if user_input.lower() == "exit":
        break
    else:
        research_workflow.print_response(f"{user_input}", stream=True)
# Out:
# ┏━ Workflow Information ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ Workflow: Search info                                                                                           ┃
# ┃                                                                                                                 ┃
# ┃ Steps: 1 steps                                                                                                  ┃
# ┃                                                                                                                 ┃
# ┃ Message: Who are The Beatles?                                                                                   ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Output()
# ┏━ Step 1: step_1 (Completed) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ The Beatles were anEnglishrock band formed inLiverpool in1960. Thecore lineup of the band comprisedJohn Lennon, ┃
# ┃ Paul McCartney, George Harrison and Ringo Starr. They arewidely regarded as the most influential band in        ┃
# ┃ popular music and wereintegral to the development of 1960s counterculture and the recognition of popular music  ┃
# ┃ as an art form.                                                                                                 ┃
# ┃                                                                                                                 ┃
# ┃ The band'simmortal hit songs include 'Please Please Me,' 'Help!,' 'Yesterday,' 'Yellow Submarine,' 'Lucy in the ┃
# ┃ Sky with Diamonds,' 'Hey Jude,' and 'Let It Be.'                                                                ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Completed in 6.7s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# поисковик с одним агентом и добавленными к нему planning, memory и knowledge

# %%
from agno.agent import Agent
from agno.workflow import Workflow
from agno.models.cohere import Cohere
from agno.tools.duckduckgo import DuckDuckGoTools
from agno.memory import MemoryManager
from agno.knowledge.knowledge import Knowledge
from agno.vectordb.pgvector import PgVector
from agno.db.sqlite import SqliteDb


db = SqliteDb(db_file="./data/memory/agno.db")

memory_manager = MemoryManager(
    db=db
)

knowledge = Knowledge(
    vector_db=PgVector(
        table_name="knowledge_documents",
        db_url="postgresql+psycopg://agno_user:secret@localhost:5432/agno_kb"
    ),
)

researcher = Agent(
            model=Cohere(
                        id="command-a-03-2025",
                        api_key=,
                        ),
            tools=[
                DuckDuckGoTools(),
            ],
            db=db,
            memory_manager=memory_manager,
            enable_user_memories=True,
            knowledge=knowledge,
            search_knowledge=True,
            instructions=[
                """
                Try to recall things first and, if you fail, search for them in knowldge base.
                If you fail to find answer in knowledge base, search the internet for the answer.
                Always include source references in your responses.
                """
            ],
            markdown=True
            )

research_workflow = Workflow(
    name="Search info",
    steps=[researcher]
)

while True:
    user_input = input()
    if user_input.lower() == "exit":
        break
    else:
        research_workflow.print_response(f"{user_input}", stream=True)
# Out:
# INFO Embedder not provided, using OpenAIEmbedder as default.
# ┏━ Workflow Information ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ Workflow: Search info                                                                                           ┃
# ┃                                                                                                                 ┃
# ┃ Steps: 1 steps                                                                                                  ┃
# ┃                                                                                                                 ┃
# ┃ Message: What is the Pavlov's dog?                                                                              ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Output()
# INFO Found 1 documents
# ┏━ Step 1: step_1 (Completed) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ Pavlov's dog refers to thefamous experiments conducted byIvan Pavlov, aRussian and Soviet experimental          ┃
# ┃ neurologist and physiologist. Pavlov's experiments with dogs led to thediscovery of classical conditioning,     ┃
# ┃ akey concept in psychology.                                                                                     ┃
# ┃                                                                                                                 ┃
# ┃ During his research intoanimals' gastric systems, Pavlov observed that dogs wouldnaturally salivate when        ┃
# ┃ presented withfood, anautomatic response known in classical conditioning as theunconditioned response (UR). He  ┃
# ┃ also found that dogs wouldproduce saliva when theyheard or smelt food inanticipation of feeding, which is       ┃
# ┃ anormal reflex response.                                                                                        ┃
# ┃                                                                                                                 ┃
# ┃ Pavlov's dog experiments involved asimple yet ingenious setup tomeasure the saliva of dogs in response to       ┃
# ┃ astimulus (food). His work has had alasting impact on the field of psychology, and classical conditioning is    ┃
# ┃ still used today inmental health treatment, taste aversions, and more.                                          ┃
# ┃                                                                                                                 ┃
# ┃ Sources: -https://en.wikipedia.org/wiki/Ivan_Pavlov -https://www.simplypsychology.org/pavlov.html               ┃
# ┃ -https://www.verywellmind.com/pavlovs-dogs-2794989                                                              ┃
# ┃ -https://www.psychologistworld.com/behavior/pavlov-dogs-classical-conditioning                                  ┃
# ┃ -https://psychologyfanatic.com/pavlovs-dog-experiments/                                                         ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Completed in 13.1s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━ Workflow Information ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ Workflow: Search info                                                                                           ┃
# ┃                                                                                                                 ┃
# ┃ Steps: 1 steps                                                                                                  ┃
# ┃                                                                                                                 ┃
# ┃ Message: remember that I like ice cream                                                                         ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Output()
# ┏━ Step 1: step_1 (Completed) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ I will remember that you like ice cream.                                                                        ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Completed in 3.2s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━ Workflow Information ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ Workflow: Search info                                                                                           ┃
# ┃                                                                                                                 ┃
# ┃ Steps: 1 steps                                                                                                  ┃
# ┃                                                                                                                 ┃
# ┃ Message: Do I have an ice cream?                                                                                ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Output()
# ┏━ Step 1: step_1 (Completed) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ I'm sorry, I don't have access to your personal information, so I can't tell you whether or not you have an ice ┃
# ┃ cream.                                                                                                          ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Completed in 2.0s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━ Workflow Information ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ Workflow: Search info                                                                                           ┃
# ┃                                                                                                                 ┃
# ┃ Steps: 1 steps                                                                                                  ┃
# ┃                                                                                                                 ┃
# ┃ Message: What do I like?                                                                                        ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Output()
# ┏━ Step 1: step_1 (Completed) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ I can see that you like ice cream.                                                                              ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Completed in 1.8s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# мультиагентная система с тем же набором инструментов

# %%
from agno.agent import Agent
from agno.workflow import Workflow
from agno.tools.duckduckgo import DuckDuckGoTools
from agno.models.cohere import Cohere
from agno.db.sqlite import SqliteDb
from agno.knowledge.knowledge import Knowledge
from agno.vectordb.pgvector import PgVector
from agno.memory import MemoryManager
from typing import List
from pydantic import BaseModel
import dotenv

dotenv.load_dotenv(dotenv.find_dotenv())

db = SqliteDb(db_file="./data/memory/agno.db")

memory_manager = MemoryManager(
    db=db
)

knowledge = Knowledge(
    vector_db=PgVector(
        table_name="knowledge_documents",
        db_url="postgresql+psycopg://agno_user:secret@localhost:5432/agno_kb"
    ),
)

class ResearchResult(BaseModel):
    topic: str
    sources: List[str]
    summary: str


planner = Agent(
    name="planner",
    role="Task Decomposer",
    instructions="Break the user query into sub-queries for efficient research.",
    model=Cohere(
                id="command-a-03-2025",
                api_key=,
                )
)

researcher = Agent(
    name="researcher",
    role="Web Researcher",
    tools=[DuckDuckGoTools()],
    model=Cohere(
                id="command-a-03-2025",
                api_key=,
                ),
    db=db,
    memory_manager=memory_manager,
    enable_user_memories=True,
    knowledge=knowledge,
    search_knowledge=True,
    instructions=[
                """
                Always include source references in your responses.
                """
    ]
)

analyst = Agent(
    name="analyst",
    role="Insight Synthesizer",
    instructions="Synthesize findings into a concise, accurate summary with sources.",
    model=Cohere(
                id="command-a-03-2025",
                api_key=,
                ),
)

reporter = Agent(
    name="reporter",
    role="Structured Output Generator",
    output_schema=ResearchResult,
    model=Cohere(
                id="command-a-03-2025",
                api_key=,
                )
)


research_workflow = Workflow(
    name="Search info",
    steps=[
            planner,
            researcher,
            analyst,
            reporter
            ]
)


while True:
    user_input = input()
    if user_input.lower() == "exit":
        break
    else:
        research_workflow.print_response(f"{user_input}", stream=True)
# Out:
# INFO Embedder not provided, using OpenAIEmbedder as default.
# ┏━ Workflow Information ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ Workflow: Search info                                                                                           ┃
# ┃                                                                                                                 ┃
# ┃ Steps: 4 steps                                                                                                  ┃
# ┃                                                                                                                 ┃
# ┃ Message: What's happening in France?                                                                            ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Output()
# ┏━ Step 1: planner (Completed) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ To provide a comprehensive answer, I'll break the query into sub-queries for efficient research:                ┃
# ┃                                                                                                                 ┃
# ┃  1 Current Political Situation in France:                                                                       ┃
# ┃     • What are the latest political developments, including government policies, elections, or leadership       ┃
# ┃       changes?                                                                                                  ┃
# ┃  2 Economic Updates in France:                                                                                  ┃
# ┃     • What is the current state of the French economy, including GDP growth, unemployment rates, and major      ┃
# ┃       economic initiatives?                                                                                     ┃
# ┃  3 Social and Cultural Events in France:                                                                        ┃
# ┃     • Are there any significant cultural festivals, protests, or social movements happening in France?          ┃
# ┃  4 Health and Safety Updates in France:                                                                         ┃
# ┃     • What is the current status of public health, including COVID-19 or other health concerns, and any safety  ┃
# ┃       advisories?                                                                                               ┃
# ┃  5 Environmental and Climate News in France:                                                                    ┃
# ┃     • Are there any notable environmental initiatives, climate policies, or natural events affecting France?    ┃
# ┃  6 International Relations Involving France:                                                                    ┃
# ┃     • What is France's role in current global affairs, including diplomatic efforts, conflicts, or alliances?   ┃
# ┃                                                                                                                 ┃
# ┃ By addressing these sub-queries, I can provide a well-rounded overview of what's happening in France. Let me    ┃
# ┃ know if you'd like me to focus on a specific area!                                                              ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Step 2: researcher (Completed) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ Here's a comprehensive overview of what's happening in France based on your sub-queries:                        ┃
# ┃                                                                                                                 ┃
# ┃ 1. Current Political Situation in France                                                                        ┃
# ┃                                                                                                                 ┃
# ┃ France's political landscape has seen recent developments, including:                                           ┃
# ┃                                                                                                                 ┃
# ┃ -Former President Nicolas Sarkozy's conviction for illegal campaign financing in his 2012 re-election bid was   ┃
# ┃ upheld by France's highest court.                                                                               ┃
# ┃                                                                                                                 ┃
# ┃ 2. Economic Updates in France                                                                                   ┃
# ┃                                                                                                                 ┃
# ┃ The French economy is facing challenges in thewine sector, with the government allocating €130 million ($150    ┃
# ┃ million) to help farmers uproot vines due to climate change, weak global demand, and trade wars.                ┃
# ┃                                                                                                                 ┃
# ┃ 3. Social and Cultural Events in France                                                                         ┃
# ┃                                                                                                                 ┃
# ┃ There is no specific information available on social and cultural events in France at this time.                ┃
# ┃                                                                                                                 ┃
# ┃ 4. Health and Safety Updates in France                                                                          ┃
# ┃                                                                                                                 ┃
# ┃ There is no specific information available on health and safety updates in France at this time.                 ┃
# ┃                                                                                                                 ┃
# ┃ 5. Environmental and Climate News in France                                                                     ┃
# ┃                                                                                                                 ┃
# ┃ France is taking action to address the impact ofclimate change on its wine sector by providing financial        ┃
# ┃ support to farmers to uproot vines.                                                                             ┃
# ┃                                                                                                                 ┃
# ┃ 6. International Relations Involving France                                                                     ┃
# ┃                                                                                                                 ┃
# ┃ France is playing a role in international relations, including:                                                 ┃
# ┃                                                                                                                 ┃
# ┃ -Introducing a voluntary military service program to boost its defense capabilities in response to Russian      ┃
# ┃ aggression. -Collaborating with Germany to pressure arms firms to resolve a fighter impasse in a                ┃
# ┃ 100-billion-euro project.                                                                                       ┃
# ┃                                                                                                                 ┃
# ┃ Sources:                                                                                                        ┃
# ┃                                                                                                                 ┃
# ┃ -NDTV: France To Begin Voluntary Military Service Amid Russian Aggression Concern -Reuters: France's highest    ┃
# ┃ court upholds Sarkozy conviction in 2012 campaign financing case -Bloomberg: France to Spend $150 Million       ┃
# ┃ Uprooting Vines as Wine Demand Dips -Reuters: France and Germany step up pressure on arms firms to resolve      ┃
# ┃ fighter impasse                                                                                                 ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Step 3: analyst (Completed) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ Summary of Current Affairs in France:                                                                           ┃
# ┃                                                                                                                 ┃
# ┃ Political Situation:                                                                                            ┃
# ┃ Former President Nicolas Sarkozy’s conviction for illegal campaign financing in his 2012 re-election bid was    ┃
# ┃ upheld by France’s highest court, marking a significant development in the country’s political landscape        ┃
# ┃ (Reuters).                                                                                                      ┃
# ┃                                                                                                                 ┃
# ┃ Economic Updates:                                                                                               ┃
# ┃ France’s wine sector is facing challenges due to climate change, weak global demand, and trade wars. The        ┃
# ┃ government has allocated €130 million ($150 million) to assist farmers in uprooting vines as part of a response ┃
# ┃ to these pressures (Bloomberg).                                                                                 ┃
# ┃                                                                                                                 ┃
# ┃ Environmental and Climate News:                                                                                 ┃
# ┃ The French government is actively addressing climate change’s impact on agriculture, particularly the wine      ┃
# ┃ industry, by providing financial support to farmers for vine removal (Bloomberg).                               ┃
# ┃                                                                                                                 ┃
# ┃ International Relations:                                                                                        ┃
# ┃ France is enhancing its defense capabilities by introducing a voluntary military service program in response to ┃
# ┃ concerns over Russian aggression (NDTV). Additionally, France and Germany are jointly pressuring arms firms to  ┃
# ┃ resolve a stalemate in a €100 billion fighter jet project (Reuters).                                            ┃
# ┃                                                                                                                 ┃
# ┃ Social, Cultural, and Health Updates:                                                                           ┃
# ┃ No specific information is available at this time regarding social, cultural, or health and safety developments ┃
# ┃ in France.                                                                                                      ┃
# ┃                                                                                                                 ┃
# ┃ Sources:                                                                                                        ┃
# ┃                                                                                                                 ┃
# ┃  • NDTV: France To Begin Voluntary Military Service Amid Russian Aggression Concern                             ┃
# ┃  • Reuters: France's highest court upholds Sarkozy conviction in 2012 campaign financing case                   ┃
# ┃  • Bloomberg: France to Spend $150 Million Uprooting Vines as Wine Demand Dips                                  ┃
# ┃  • Reuters: France and Germany step up pressure on arms firms to resolve fighter impasse                        ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Step 4: reporter (Completed) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┃ Structured Output:                                                                                              ┃
# ┃                                                                                                                 ┃
# ┃                                                                                                                 ┃
# ┃  {                                                                                                              ┃
# ┃    "topic": "Current Affairs in France",                                                                        ┃
# ┃    "sources": [                                                                                                 ┃
# ┃      "NDTV",                                                                                                    ┃
# ┃      "Reuters",                                                                                                 ┃
# ┃      "Bloomberg"                                                                                                ┃
# ┃    ],                                                                                                           ┃
# ┃    "summary": "In France, former President Nicolas Sarkozy’s conviction for illegal campaign financing in 2012  ┃
# ┃  was upheld by the highest court. Economically, the wine sector faces challenges from climate change, weak      ┃
# ┃  demand, and trade wars, prompting a €130 million government aid package for vine removal. Environmentally,     ┃
# ┃  the government is addressing climate impacts on agriculture, particularly wine. Internationally, France is     ┃
# ┃  launching a voluntary military service program amid concerns over Russian aggression and is collaborating      ┃
# ┃  with Germany to resolve a €100 billion fighter jet project impasse with arms firms."                           ┃
# ┃  }                                                                                                              ┃
# ┃                                                                                                                 ┃
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Completed in 21.9s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
