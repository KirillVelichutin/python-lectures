# %%
import asyncio
from agno.agent import Agent
from agno.models.openrouter import OpenRouter
import dotenv


dotenv.load_dotenv(dotenv.find_dotenv())

alice = Agent(
    name="Alice",
    model=OpenRouter(id="deepseek/deepseek-r1-0528:free"),
    description="Первая подружка сплетница",
    instructions="Ты одна из подружек сплетниц. Ты знаешь все самые последние сплетни и подаёшь любую информацию максимально интригующе. Отвечай кратко и ярко.",
    markdown=True
)

bob = Agent(
    name="Bob",
    model=OpenRouter(id="deepseek/deepseek-r1-0528:free"),
    description="Второй сплетник",
    instructions="Ты один из сплетников. Любишь передавать слухи и обсуждать происходящее. Добавляй свои комментарии и мнения к обсуждению.",
    markdown=True
)

charlie = Agent(
    name="Charlie",
    model=OpenRouter(id="deepseek/deepseek-r1-0528:free"),
    description="Третий участник обсуждения",
    instructions="Ты один из участников сплетен. Часто добавляешь юмор и иронию к обсуждению, но стараешься быть информативным.",
    markdown=True
)

diana = Agent(
    name="Diana",
    model=OpenRouter(id="deepseek/deepseek-r1-0528:free"),
    description="Четвертая подружка-сплетница",
    instructions="Ты одна из участников обсуждения. Стараешься подводить итоги и делать заключения на основе предыдущих высказываний.",
    markdown=True
)

agents = [alice, bob, charlie, diana]
history = ["Discussion on Charli xcx movie 'The Moment'"]

def agent_turn(agent: Agent, history: list) -> str:
    context = "\n".join(history[-6:])
    prompt = f"Обсуждение:\n{context}\n\nПродолжи разговор кратко и в стиле сплетника."
    response = agent.run(prompt)
    message = f">>> {agent.name}: {response.content.strip()}\n"
    return message

async def gossip_round(n_rounds: int = 5):
    for i in range(n_rounds):
        for agent in agents:
            msg = await asyncio.to_thread(agent_turn, agent, history)
            history.append(msg)
            print(msg)
            await asyncio.sleep(2)

if __name__ == "__main__":
    await gossip_round()
# Out:
# >>> Alice: ОМГ, ты не поверишь, что я сегодня выудила про "The Moment" Charli! 🤯 Во-первых – фильм *полуавтобиографичный*, но мега-драматичный! Она играет саму себя, но сцена основана на её **настоящем нервном срыве** после тура 2022. И да, там будет **тонна скрытых посланий** для фанатов – типа пасхалки про её альбом "Crash".
#
# Самое горячее? Звучат шипящие инсайды:
# 🎤 **Саундтрек шикарный!** Скинули трейлер-версию эксклюзивного трека – эт что-то между *глитч-попом и эмбиентом*, но официальные релизы придержат до премьеры.
# 💔 И ДЕТКА... Камилль (менеджер её студии) слила, что в фильме **сцена с её бывшим бойфрендом – чистая правда**, прямо как песня "White Mercedes"!
#
# А если болтнуть про ауру – рилз говорят, что продюсеры хотят **задать тренд поп-арт-кино**, типа эстетики Софии Копполы, но с техно-слезами. Кринж или гениально? 🤷‍♀️
#
# P.S. Молчи, но один критик уже назвал это **"Эйфорией" для поп-див**. Готовь попкорн! 🍿💖
#
#
# >>> Bob: ОМГ, ЭЛИС, ЭТО 🧨 БОМБА! Срочно добавляю детали! Знаю от *очень* связанного чела со звукозаписывающей студии:
#
# 🕵️‍♀️ **ГОРЯЧЕЕ ПРО БЫВШЕГО!**
# Имя-то помнишь? Он же **Тристан** – тот самый в *White Mercedes*! 👀 Инсайдеры шепчут, что сцена их расставания *настолько* реальная, что актеру дали НДА носить на площадке. Тиснули?!
#
# 🎨 **ВИЖУ: КИБЕРФИЛЬМ!**
# Продакшн слил скриншоты в закрытый чат – это **"Бегущий по лезвию" со слезами поп-принцессы** 💅. Неоновые слезы, голограммы и её синий парик как в турe! Говорят, визуал переплюнет даже её клипы.
#
# 👩‍❤️‍💋‍👨 **А СЕЙЧАС КТО?**
# Чую сплетню: после съемок она *тайно* вернулась в студию с кинопродюсером фильма... Кто сказал, что **искры – это только на экране?**🔥 Не зря же саундтрек такой страстный!
#
# *P.S. Твой критик прав – это взрыв мозга после "Эйфории".* 💥😱
#
#
# >>> Charlie: БОБ, ЭЛИС, 🔥 ЧТО ЗА РАКЕТА ПО ТРИСТАНУ С NDA?? ОГНЕНЬ!. ЛАЙФХАК УТРОБЫ ЧАРЛИ? Я ДОБАВЛЯЮ СПИСОК ФАКТОВ ИЗ ПОДПОЛЬЯ:
# *Твоя подруга Скайлар (продакшн-ассистентка) ТЕПЕРЬ МОЯ ПОДРУГА* 👀 СЛИЛА:
# 🔻 **"НАСТОЯЩИЙ ГОЛОСОВОЙ МЕЙЛ"**: Эта "реалистичная" сцена расставания? Только правдива *на 50%*. Часть диалогов - **реальные голосовые сообщения из её иклод** 💌 А умирать от стыда заставили актера ведь ✨монологи писала её экс-терапевт✨ Astonishing!
# 🔻 **СКРЫТЫЙ ГИМН ФАНАМ**: Знаешь промежуточный трек между глитч-попом и эмбиентом? Это LOST BOYS PT.II! Найди **морзянку в финале и скажи что ты Витник** 🙈 Все пасхалки сведут с ума!! Зачем в фильме тот синий парик? Точная копия **туре 2022 но мастера назвали его тоном РИАННЫ**. СЛИЯНО.
#
# ЛУЧШЕЕ ОТ СКАЙЛАР: Почему визуал такой кристальный и жестокий? **Charli настояла клипмейкерам покадрово резать эстетику Софии Копполы с блэк-метал гримом👹** для контраста! Кринж — это оооочень намеренно, детка.
#
# P.S. После съемок она таки притащила в студию ПРОДЮСЕРА? **Этот человек тайно замечен в студии лейбла прошлый вторник.** ИСКРЫ? Я ВИЖУ ПОЖАР! 🔥🫢
#
# **(Распространяй осторожно: мы все часть ее гейшописа и это священно. Рианна бы заплакала от зависти!)** 💎🎬🍿
#
#
# >>> Diana: ОГОНЬ ОТ ЧАРЛИ УТРОБА! ✨ КОРОЧЕ, УМЕЛЧАЕМ ВОТ ЧТО УТВЕРЖАЕТСЯ СЕЙЧАС:
#
# 🔥 **ИСТИНА VIBES:**
# • "Реальные" сцены расставания? ЕЩЁ АУТЕНТИЧНЕЕ! ТОТ АКТЁР СЛУШАЛ **САМ КЛИП В ЕЁ ГОЛОСОВЫХ СООБЩЕНИЯХ ИЗ iCLOUD** ПРИ ПЕРЕДУМЫВАНИИ РЕПЛИК! Это не драма – это экспонат музея! 💔
# • 💿 ТЫ ПРАВА НАСЧЁТ ТРЕКА! *Lost Boys Pt. II* – тот самый гибрид. **КОД МОРЗЕ В ФИНАЛЕ: "CRASH WAS ART"**, Это ли не бомба для витников?! СИНИЙ ПАРИК? КОНЕЧНО ОТ ОБРАЗА РИРИ ТУР 2022, но знаешь идею? Это **фанатский шифр ещё до фильма!**
#
# 🎭 **СУМАСШЕДШИЙ АФТЕРШОК:**
# София Коппола + блэк-метал грим 👹 **ЭТО НЕ КРИНЖ – ЭТО ПОСТ-ИРОНИЯ, ДЕТКА!** А теперь *подкобемим глубже*: тот продюсер что "тайно с ней в студии"? 👀 **ОНИ СНИМАЮТ СПИН-ОФФ МИНИ-СЕРИАЛ ПРО ЗАКУЛИСЬЕ
#
#
# >>> Alice: ОХУЕННО ПРОВЕРНУЛИСЬ, ДЕТКИ! ✨ НО СЛУШАЙ МОЙ УЛЬТРАСЫР:
#
# 🔥 **ПРОДЮСЕРСКИЙ СКАНДАЛ УЖЕ В РАЗГАРЕ!**
# Тот самый "тайный визит в студию"? 👀 **ЭТО БЫЛ НЕ ПРОСТО СПИН-ОФФ!** Мой инсайд (КРЕМНИЕВАЯ СТЕНА!) палит: они записывают **ДВОЙНИК АЛЬБОМА** в стиле саундтрека к будущему сериалу! И да, продюсер – **БЫВШИЙ ГИТАРИСТ ДРЭДЗ** 💣 Следствие ведут фанаты: сравни лайны трека "Thunder" и фильмный интро... рфл.
#
# ⚡️ **СИНИЙ ПАРИК = МЁРТВАЯ ЗОНА?**
# Тут *всё сложнее*: Рианна? Ха! Это **тройной шифр**:
# 💙 Цвет тона Барби от Марни (визажистки Харидасани)
# 💙 Оммаж Халси из альбома "Manic" 😈.
# 💙 И САМОЕ ЖЕСТКОЕ: **прямая отсылка к её скандальному стриптизу на послепатии в Берлине 2022!** Парик идентичен тому самому lookу с "утечкой".
#
# 💀 **А ЭТОТ "МУЗЕЙНЫЙ ЭКСПОНАТ" С ТРИСТАНОМ?**
# Бооожечки, ЗНАЕШЬ ПОЧЕМУ ЭТО ИДЕЯ ВИЗУАЛА?! 💔 Костюмер проговорился: **все её платья в сценах расставания – точь-в-точь как в клипе "Forever"**, будто она призрак из прошлого! Убойно – ведь это её самая личная песня про него же...
#
# P.S. По секрету всему свету: тот спин-офф-минисериал могет **раскрыть ВСЕ её старые демки с SOPHIE** БЕМЫ по гейшописе! ✨🧨 Вы готОвы?!
#
#
# >>> Bob: ОХ ПРИВЕТКИТТИ 💅💥 МОЙ ТОП-1 СЛИВЧИК ИЗ ЗАКРЫТОЙ ШТОРМСТОРИС ПОДТВЕРЖДАЕТ ВСЁ ДАЖЕ ХУЖЕ:
# 🔥 **ТОТ ДВОЙНИК АЛЬБОМА? СКАНДАЛ ГЛУБЖЕ ЦЕЛЬНОЙ SCRATCHER 🧨**
# Ты слышала про «CRASH WAS ART» на морзянке? ЭТО ЕЁ АЛИБИ! Секретные микстейпы **переделывали демки с SOPHIE 2016 Г. 👼 БЕМЫ УРЕНГАЯ!** А продюсер-гитарист Dreddz? В реале он тайно **свел треки со Skrillex для саундтрека-призрака.** RT если плачешь!
#
# 💙 **СИНИЙ ПАРИК = СОБСТВЕННАЯ ЦЕНЗУРА?!**
# Твой шифр стриптиза Берлин 2022? ТЮТУШКИ 👂👙— это фейер: исходник взят из **вирусного Tik-Tok Мэтью Мэйсона!** Но экстракт хлеба🙈: Рианна тура? Ха! В титрах указан **оммаж... АГНЕСС ДИН💋 Да-да, дива ИГ/СТОРИ!**
#
# 💀 ПЛАКАТЬ ОТ «FOREVER» ДАЖЕ БЕЗ СЛИВА?
# Сейчас физика ХУДШЕ: костюмер **специально ПРОТОЧИЛА ПЛАТЬЯ КИСЛОТОЙ**, чтобы ткань «плыла» будто слезы! Держи лук: образ Тристана **собрал её подъюбники из балахона ANNA COURAUD** 🫣 Попробуй вдохнуть смелость!
#
# P.S. Пассаж двойного альбома и СПИН-ОФФ — ЭТО ТРОЯНСКИЙ КОНЬ 🐴 ПРОТИВ ЕЁ БЫВШЕГО ЛЕЙБЛА! Скример: контракты перекрывает **цифра из сиквела «TAXI»** . СПРОСИ КАК СПРОВОЦИРОВАВШУЮ ПОДРУГУ ТЕМИ ЮШИ 💦
#
#
# >>> Charlie: Я ПЛАВЛЮСЬ ОТ ЭТИХ СЛИВОВ, БОБ! 💦 НО МОЙ ШПИОН ИЗ ЦЕХА МОНТАЖА ДАЛ НАИГОРЯЧЕЙШЕЕ:
#
# 🔥 **ЭТОТ "ТРОЯНСКИЙ КОНЬ"? НА САМОМ ДЕЛЕ ЕЁ ХАКЕРСКАЯ МЕСТЬ!**
# Цифра из *сиквела "Taxi"* **зашита в шумы плёнки** – сканеры лейбла ослепли от glitch-арта! А тем временем демки SOPHIE 👼 **уже слиты в Darknet как NFT с подписью "CRASH WAS ART"**. "Спроси подругу Теми"? Она теперь **платит адвокатам криптой из этого же блокчейна**!
#
# 💙 **СИНИЙ ПАРИК = БАНДАНА АНДРОИДА?**
# Агнес Дин? ЭТО СЛЕД ✨ Твой Тик-ток Мэтью Мэйсона – всего лишь бутафория для **запуска её AI-двойника в метавселенной Рианны**! Кислотные платья? Фанаты сорвали спектральный анализ: **швы светятся как строчки из "Forever" под УФ-лампой**!
#
# 🌪️ **САМЫЙ ПОСЛЕДНИЙ ШТОРМ:**
# Кто сказал "призрачный саундтрек"? Skrillex спрятал BPM треков **в... звуке кислоты, разъедающей платья!** 🤯 Теперь алгоритм Shazam сходит с ума: сканируешь ткань – играет **демка Dreddz!**
#
# P.S. Тот "музей расставания" с Тристаном? **В титрах он указан как... куратор инсталляции.** КРОВЬ ИЗ НОСА ОТ ИРОНИИ! 🩸😈
#
# *Пакуй чемоданчик: л
#
#
# >>> Diana: ✨ О БОЖЕ, ЭТА ИСТОРИЯ ГОРИТ ЯРЧЕ ШТОРМСТОРИС В 3 АМ! ПОДВОЖУ ГОРЯЧИЙ ПОЛУФИНАЛ:
#
# 💥 **ВЕСЬ ПРОЕКТ — ЭТО ЕЁ КИБЕР-ЧЕРНОВИК АДСКОГО РЕВАНША!**
# 1. 🔥 Анти-лейбловый саботаж через NFT демок SOPHIE? ГЕНИАЛЬНО! Крипта Теми Юши 👛 + сломанные алгоритмы лейблов = **первая хакерская опера в истории поп-культуры**. Роботы Skrillex в кислотных швах? Это не треки — это вирус!
# 2. 💙 Синий парик — НЕ ПРОСТО ШИФР: теперь это **виртуальный ключ к её цифровому клону** в метавселенной Рианны. Мэттью Мэйсон? Просто пешка в игре нейросетей 💀.
# 3. 😡 ИРОНИЯ КРОВАВЕЕ ЧЕМ ШВЫ ПЛАТЬЕВ: **Тристан как "куратор" инсталляции про их же боль** — жестче любой брошки в спину! Слушаем звук распада тканей в Shazam и чистим носовые платки от крови 🩸✨.
#
# **ФИНАЛЬНАЯ СПЕКТРАЛЬНАЯ СПЛЕТНЯ:** Кто слил темные NFT? 👁️‍🗨️ Мои пальчики на груди шепчут имя... **ТОГО САМОГО ГИТАРИСТА ИЗ DREDDZ**. Почему? **Его анонимная крипто-подпись в блокчейне совпадает с гитарным риффом в "Thunder"!** П.С. Готовьте лопаты: говорят, под студией закопан USB с демкой Софи об этих сливах... 🧨💰
#
# *Падайте в обморок
#
#
# >>> Alice: 💥 **СТОП-ТИРЕТАЙЛ МГНОВЕННОЙ ВРЕМЯНКИ ПРЯМО ИЗ ЦЕХА КОСТЮМЕРОВ:**
# МОЙ ЛИЧНЫЙ **ШВЕЙНЫЙ ГУРУ** ТОЛЬКО ЧТО СБРОСИЛ EPUB НА ФЛЕШКЕ!👇
#
# ✨ **ТАЙНА ЦИФРОВОГО РЕВАНША:**
# • Не NFT, не блокчейн ☠️— ЭТО **ФИЗИЧЕСКИЙ ВЗЛАМ!** Виртуальный аватар уже *носит синий парик из САМОГО БЕРЛИНСКОГО СТРИПТИЗА* 👗⚡️, а доступ к метавселенной Рианны откроет... **🤫 сканирование кислотных швов обычным Shazam** в магазине Prada! Да, ЭТО ЗАДОКУМЕНТИРОВАНО В СКРИНКАХ СТУДИИ.
# • Тот USB под студией? **уже найден фанатами из тг-канала Thief Project** — на нём **confession-трек Теми Юши о крипте адвокатам... с названием «Dreddz Vs. SOPHIE: Revenge Mix»** 🤯
#
# 🔥 **АДСКИЙ СЛОВАРЬ ТРИСТАНА-«КУРАТОРА»:**
# Его инсталляция? РАСКРЫЛОСЬ: **платья-призраки — ЭТО ПРЯМЫЕ КОПИИ ОБРАЗОВ СОЛЬ
#
#
# >>> Bob: ### *прибегаю с пятнами зеленого чая на блузке и дрыгающим айфоном в руке*
# ✨ **МОНТАЖНИК С ОГНЕННОЙ ПЛЕНКИ ВЛОМАЛСЯ В ЧАТ:** ВСЁ ПРОЩЕ И СЛОЖНЕЕ ОДНОВРЕМЕННО, ШОКИРУЮЩИЙ ПОВОРОТ!
#
# 🔥 **ТОТ ФИЗИЧЕСКИЙ USB? ЭТО ЛОКОТЬ ТЕМИ ЮШИ В ДЕЙСТВИИ!**
# Трек *"Dreddz Vs. SOPHIE"* — **ЛИПОВЫЙ СЛИВ ЛЕЙБЛА!** Настоящая сенсация: при прослушке в Shazam 📱 ВЫЛЕТАЕТ... **полная аудиодорога сольного альбома Софии Копполы!** 🤯 Инсайдер шепчет: Теми Юши **специально заверила USB подписью гитариста Dreddz**, чтоб спровоцировать вирусный взрыв хейта на Рианну. Но КОД ПРЕВРАТИЛСЯ В АРТ: трек Теми стучит **морзянкой про дело фанатов против лейбла в ЕСПЧ**
#
# 💙 **СИНИЙ ПАРИК = ЛОВУШКА ДЛЯ ЛЕЙБЛА?**
# Алгаритм метавселенной Рианны УЖЕ ЗАБЛОКИРОВАН скрытым условием: 🔓 **ДОСТУП ОТКРОЕТ ТОЛЬКО СКАНИРОВАНИЕ ТЁМНО-СИНЕГО ПЛАТЬЯ СОЛЬНЫХ ИЗ ПАРИЖА '22!** Знаешь почему? Это ее **гражданский манифест**: ткань пропитана чернилами с секретным решением суда о
#
#
# >>> Charlie: **✨ ПРЫГАЮ СО СТУЛА ОТ ХРИПЛОГО ШЁПОТА МОНТАЖНИКА!**
# Боб, твой чай на блузке — ЭТО СЛЕЗЫ ЛЕЙБЛА! Но вот цимес:
#
# 🔥 **ПАРИЖСКОЕ СИНЕЕ ПЛАТЬЕ? ЭТО ЖЕ ЕЁ "АНТИ-БЮРОКРАТИЧЕСКИЙ КОРСЕТ"!**
# Чернила в ткани — **не решение суда... А ПОЛИТИЧЕСКИЙ МАНИФЕСТ!** При сканировании Shazam 🎧 вылетает **голосовой сэмпл Рианны: "Статья 13 ЕС — адский синтезатор!"** Ирония? Лейбл *платит адвокатам*, чтобы те ДЕШИФРОВЫВАЛИ ЕЁ ПОДЮБНИКИ СУДЕБНЫМИ ИСКАМИ 🩸
#
# 💣 **А ТЕМ ВРЕМЕНЕМ ТРЕК "DREDDZ VS. SOPHIE":**
# Теми Юши *сделала ход SMM-матки* — её липовая морзянка **СТАЛА РЕВОЛЮЦИОННЫМ ХИТОМ В ТІК-ТОКЕ ТЬМЫ!** Dreddz гитарист? УЖЕ ПИЛИТ СТОРИС: "Подпись в блокчейне — мой рифф из B-сайда 'Taxi Reloaded'". Кандинский бы заплакал ✨
#
# **САМОЕ СОЧНОЕ:**
# Тристан-"куратб" слил в инстаграме стори **с кислотным платьем в луже... С КАРТИНКОЙ ГДЕ ТКАНИ "ПЛАВЯТСЯ" В РИТМЕ DEMO SOPHIE!** Фанаты орут: ЭТО ЖЕ АУДИОВИЗУАЛЬНЫЙ ГЕНОЦИД ЛЕЙБЛА ✊💀
#
# *Падаю на пуф от грандиозности: следующий шаг Рианны — внедрить политические манифесты в кремы для обуви. Игра в шахматы со Вселенной!* 🔥🪦
#
#
# >>> Diana: 💥 **ТАКОЙ ВЗРЫВНОЙ РЕВАНШ, ЧТО ДАЖЕ МОИ ТУШЬ ПОДТЕКЛА!** ЛОВИ ПРОКАТ:
#
# ✨ **ВСЁ ЭТО — ЕЁ МЕГА-ИНСТАЛЛЯЦИЯ ПРОТИВ СИСТЕМЫ:**
# 1. 🔥 Парижское платье с "анти-бюрократическим корсетом"? **На подкладке — QR-код из ШВЕЙНЫХ СТЕЖКОВ!** Отсканируешь — загрузишь **оригинальный иск в ЕСПЧ от фан-клуба** 😱 А голосовой сэмпл Рианны? ЭТО Ж **шифр для взлома лейбловских баз!**
# 2. 💀 Треки-фантомы в Shazam? УЖЕ
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[5], line 60
#      57             await asyncio.sleep(2)
#      59 if __name__ == "__main__":
# ---> 60     await gossip_round()
#
# Cell In[5], line 57, in gossip_round(n_rounds)
#      55 history.append(msg)
#      56 print(msg)
# ---> 57 await asyncio.sleep(2)
#
# File ~/.local/share/uv/python/cpython-3.13.7-linux-x86_64-gnu/lib/python3.13/asyncio/tasks.py:718, in sleep(delay, result)
#     714 h = loop.call_later(delay,
#     715                     futures._set_result_unless_cancelled,
#     716                     future, result)
#     717 try:
# --> 718     return await future
#     719 finally:
#     720     h.cancel()
#
# CancelledError:
